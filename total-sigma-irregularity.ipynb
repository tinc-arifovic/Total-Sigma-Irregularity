# %%
import random
import math
from itertools import combinations

# %%
def sigma1 (G):
    n = order(G)
    return sum((abs(u-v)) ** (1/n) for u, v in combinations(G.degree(),2))

# %%
def sigma2 (G,c):
    n = order(G)
    return sum((abs(u-v)) ** c/100 for u, v in combinations(G.degree(),2))

# %%
def sigma3 (G): # dodati je treba izbrane funkcije
    n = order(G)
    return sum((abs(u-v)) ** (1/n) for u, v in combinations(G.degree(),2))

# %%
def indeksi_maksimalnih_elementov(seznam):
    maks_vrednost = max(seznam)
    indeksi = [i for i, vrednost in enumerate(seznam) if vrednost == maks_vrednost]

    return indeksi

# %%
def max_total_sigma_irregularity1(n):
    grafi = list(graphs(n))
    sigme = list()
    for G in range(len(grafi)):
        sigme.append(sigma1(grafi[G]))
    koncni_grafi = list()
    for i in indeksi_maksimalnih_elementov(sigme):
        koncni_grafi.append(grafi[i])
    for graf in koncni_grafi:
        graf.show()
    return None

# %%
def max_total_sigma_irregularity2(n):
    grafi = list(graphs(n))
    sigme = list()
    for c in range(0,100,5):
        for G in range(len(grafi)):
            sigme.append(sigma2(grafi[G],c))
    koncni_grafi = list()
    for i in indeksi_maksimalnih_elementov(sigme):
        koncni_grafi.append(grafi[i])
    for graf in koncni_grafi:
        graf.show()
    return None

# %%
grafi = list(graphs(4))
sigme = list()
for c in range(0,100,5):
    for G in range(len(grafi)):
        sigme.append(sigma2(grafi[G],c))
sigme
# Out:
# [3/50,
#  3/50,
#  3/50,
#  3/50,
#  3/50,
#  3/50,
#  3/50,
#  3/50,
#  3/50,
#  3/50,
#  3/50,
#  0,
#  1/25,
#  9/25,
#  24/25,
#  0,
#  1/25,
#  24/25,
#  9/25,
#  0,
#  1/25,
#  0,
#  0,
#  1/25,
#  257/25,
#  768/25,
#  0,
#  1/25,
#  768/25,
#  257/25,
#  0,
#  1/25,
#  0,
#  0,
#  1/25,
#  8193/25,
#  24576/25,
#  0,
#  1/25,
#  24576/25,
#  8193/25,
#  0,
#  1/25,
#  0,
#  0,
#  1/25,
#  52429/5,
#  786432/25,
#  0,
#  1/25,
#  786432/25,
#  52429/5,
#  0,
#  1/25,
#  0,
#  0,
#  1/25,
#  8388609/25,
#  25165824/25,
#  0,
#  1/25,
#  25165824/25,
#  8388609/25,
#  0,
#  1/25,
#  0,
#  0,
#  1/25,
#  268435457/25,
#  805306368/25,
#  0,
#  1/25,
#  805306368/25,
#  268435457/25,
#  0,
#  1/25,
#  0,
#  0,
#  1/25,
#  8589934593/25,
#  25769803776/25,
#  0,
#  1/25,
#  25769803776/25,
#  8589934593/25,
#  0,
#  1/25,
#  0,
#  0,
#  1/25,
#  54975581389/5,
#  824633720832/25,
#  0,
#  1/25,
#  824633720832/25,
#  54975581389/5,
#  0,
#  1/25,
#  0,
#  0,
#  1/25,
#  8796093022209/25,
#  26388279066624/25,
#  0,
#  1/25,
#  26388279066624/25,
#  8796093022209/25,
#  0,
#  1/25,
#  0,
#  0,
#  1/25,
#  281474976710657/25,
#  844424930131968/25,
#  0,
#  1/25,
#  844424930131968/25,
#  281474976710657/25,
#  0,
#  1/25,
#  0,
#  0,
#  1/25,
#  9007199254740993/25,
#  27021597764222976/25,
#  0,
#  1/25,
#  27021597764222976/25,
#  9007199254740993/25,
#  0,
#  1/25,
#  0,
#  0,
#  1/25,
#  57646075230342349/5,
#  864691128455135232/25,
#  0,
#  1/25,
#  864691128455135232/25,
#  57646075230342349/5,
#  0,
#  1/25,
#  0,
#  0,
#  1/25,
#  9223372036854775809/25,
#  27670116110564327424/25,
#  0,
#  1/25,
#  27670116110564327424/25,
#  9223372036854775809/25,
#  0,
#  1/25,
#  0,
#  0,
#  1/25,
#  295147905179352825857/25,
#  885443715538058477568/25,
#  0,
#  1/25,
#  885443715538058477568/25,
#  295147905179352825857/25,
#  0,
#  1/25,
#  0,
#  0,
#  1/25,
#  9444732965739290427393/25,
#  28334198897217871282176/25,
#  0,
#  1/25,
#  28334198897217871282176/25,
#  9444732965739290427393/25,
#  0,
#  1/25,
#  0,
#  0,
#  1/25,
#  60446290980731458735309/5,
#  906694364710971881029632/25,
#  0,
#  1/25,
#  906694364710971881029632/25,
#  60446290980731458735309/5,
#  0,
#  1/25,
#  0,
#  0,
#  1/25,
#  9671406556917033397649409/25,
#  29014219670751100192948224/25,
#  0,
#  1/25,
#  29014219670751100192948224/25,
#  9671406556917033397649409/25,
#  0,
#  1/25,
#  0,
#  0,
#  1/25,
#  309485009821345068724781057/25,
#  928455029464035206174343168/25,
#  0,
#  1/25,
#  928455029464035206174343168/25,
#  309485009821345068724781057/25,
#  0,
#  1/25,
#  0,
#  0,
#  1/25,
#  9903520314283042199192993793/25,
#  29710560942849126597578981376/25,
#  0,
#  1/25,
#  29710560942849126597578981376/25,
#  9903520314283042199192993793/25,
#  0,
#  1/25,
#  0]

# %%
# dodati je treba še eno funkcijo

# %%
max_total_sigma_irregularity1(9)
# Out:
# Graphics object consisting of 26 graphics primitives
# Graphics object consisting of 30 graphics primitives

# %%
for i in range(4,9):
    max_total_sigma_irregularity1(i)
# Out:
# Graphics object consisting of 7 graphics primitives
# Graphics object consisting of 9 graphics primitives
# Graphics object consisting of 10 graphics primitives
# Graphics object consisting of 12 graphics primitives
# Graphics object consisting of 13 graphics primitives
# Graphics object consisting of 16 graphics primitives
# Graphics object consisting of 17 graphics primitives
# Graphics object consisting of 20 graphics primitives
# Graphics object consisting of 21 graphics primitives
# Graphics object consisting of 25 graphics primitives

# %%
max_total_sigma_irregularity2(4)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/tincarifovic/Desktop/Sigma/Total-Sigma-Irregularity/total-sigma-irregularity.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/Users/tincarifovic/Desktop/Sigma/Total-Sigma-Irregularity/total-sigma-irregularity.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> max_total_sigma_irregularity2(Integer(4))
#
# /Users/tincarifovic/Desktop/Sigma/Total-Sigma-Irregularity/total-sigma-irregularity.ipynb Cell 11 line 9
#       <a href='vscode-notebook-cell:/Users/tincarifovic/Desktop/Sigma/Total-Sigma-Irregularity/total-sigma-irregularity.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a> koncni_grafi = list()
#       <a href='vscode-notebook-cell:/Users/tincarifovic/Desktop/Sigma/Total-Sigma-Irregularity/total-sigma-irregularity.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a> for i in indeksi_maksimalnih_elementov(sigme):
# ----> <a href='vscode-notebook-cell:/Users/tincarifovic/Desktop/Sigma/Total-Sigma-Irregularity/total-sigma-irregularity.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a>     koncni_grafi.append(grafi[i])
#      <a href='vscode-notebook-cell:/Users/tincarifovic/Desktop/Sigma/Total-Sigma-Irregularity/total-sigma-irregularity.ipynb#X16sZmlsZQ%3D%3D?line=9'>10</a> for graf in koncni_grafi:
#      <a href='vscode-notebook-cell:/Users/tincarifovic/Desktop/Sigma/Total-Sigma-Irregularity/total-sigma-irregularity.ipynb#X16sZmlsZQ%3D%3D?line=10'>11</a>     graf.show()
#
# IndexError: list index out of range

# %%
for i in range(4,10):
    max_total_sigma_irregularity1(i)
